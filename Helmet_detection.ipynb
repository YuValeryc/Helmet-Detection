# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q /content/drive/MyDrive/Helmet\ Detection.zip -d /content/

# %%
# !rm -rf /content/Helmet\ Detection

# %%
# %cd /content/Helmet\ Detection
# Out:
# /content/Helmet Detection

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 65.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 132.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 100.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 62.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 73.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 9.8 MB/s eta 0:00:00
# ...

# %%
# !python src/train.py
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 2025-06-16 01:58:55,772 - INFO - Found 1 GPU(s). Using device 0: Tesla T4
# 2025-06-16 01:58:55,772 - INFO - Loading pre-trained model: yolov8s.pt
# 2025-06-16 01:58:57,467 - INFO - Starting model training with the following parameters:
# 2025-06-16 01:58:57,468 - INFO -   - model: yolov8s.pt
# 2025-06-16 01:58:57,468 - INFO -   - epochs: 100
# 2025-06-16 01:58:57,468 - INFO -   - batch: 16
# 2025-06-16 01:58:57,468 - INFO -   - imgsz: 640
# 2025-06-16 01:58:57,468 - INFO -   - patience: 20
# 2025-06-16 01:58:57,468 - INFO -   - project: runs/train
# 2025-06-16 01:58:57,468 - INFO -   - name: helmet_detection_exp
# ...

# %%
from google.colab import files

model_path = r'/content/Helmet Detection/runs/train/helmet_detection_exp/weights/best.pt'
files.download(model_path)

# %%
import shutil

shutil.make_archive('helmet_detection_exp', 'zip', '/content/Helmet Detection/runs/train/helmet_detection_exp2')
# Out:
# '/content/Helmet Detection/helmet_detection_exp2.zip'
